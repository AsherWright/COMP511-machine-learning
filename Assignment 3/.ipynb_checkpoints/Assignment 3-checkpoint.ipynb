# %%
import pandas as pd
import numpy as np
import re
import collections

#data import
#taken from Reddit discussion: https://www.reddit.com/r/McGill_comp551s1/comments/7x2sdy/assignment3/
yelp_train = pd.read_csv('Datasets/yelp-train.txt',sep='\t',names=["Comment", "Evaluation"])
imdb_train = pd.read_csv('Datasets/IMDB-train.txt',sep='\t',names=["Comment", "Evaluation"])

# %%
#data clean up
def pre_process(review):
    review = re.sub('<br /><br />', '', review)
    return re.sub(r'[^a-zA-Z ]', '', review).lower()

#remove all punctuation and put to lower case
for i, row in yelp_train.iterrows():
    yelp_train.set_value(i,'Comment',pre_process(row['Comment']))
for i, row in imdb_train.iterrows():
    imdb_train.set_value(i,'Comment',pre_process(row['Comment']))

# %%
def get_vocabulary(training_set):
    # Now go through and find the frequency of each word
    unsorted_vocabulary = {}

    #populate the unsorted vocab
    for review in training_set['Comment']:
        #filter removes the blank spaces
        for word in filter(None, review.split(' ')):
            if(word in unsorted_vocabulary):
                    unsorted_vocabulary[word] += 1
            else:
                unsorted_vocabulary[word] = 1

    #now we will create a sorted vocab of the top 10000 words
    return collections.Counter(unsorted_vocabulary).most_common(10000)
# Out:
# [('the', 45289), ('and', 30384), ('a', 24943), ('i', 24105), ('to', 21039), ('of', 14411), ('was', 13707), ('is', 12071), ('it', 11542), ('for', 10615), ('in', 10183), ('that', 8244), ('my', 7557), ('with', 7537), ('but', 7279), ('you', 7155), ('this', 7010), ('they', 6398), ('on', 6343), ('have', 5982), ('we', 5763), ('not', 5237), ('had', 5011), ('are', 5010), ('place', 4573), ('good', 4533), ('so', 4484), ('at', 4482), ('were', 4194), ('food', 4144), ('be', 3900), ('as', 3877), ('there', 3546), ('great', 3508), ('like', 3425), ('if', 3179), ('its', 3170), ('me', 3144), ('all', 3134), ('just', 3114), ('very', 3068), ('out', 3043), ('here', 2912), ('one', 2744), ('or', 2718), ('get', 2671), ('their', 2655), ('from', 2562), ('up', 2420), ('go', 2373), ('really', 2351), ('when', 2347), ('our', 2337), ('time', 2330), ('about', 2297), ('some', 2240), ('would', 2107), ('service', 2076), ('an', 2063), ('what', 2025), ('your', 2025), ('can', 2013), ('been', 2010), ('which', 1989), ('back', 1961), ('more', 1832), ('dont', 1793), ('only', 1755), ('also', 1723), ('will', 1722), ('by', 1690), ('no', 1656), ('love', 1579), ('has', 1543), ('little', 1534), ('too', 1530), ('nice', 1518), ('im', 1514), ('other', 1474), ('because', 1453), ('well', 1422), ('always', 1407), ('ive', 1382), ('than', 1378), ('them', 1371), ('do', 1355), ('even', 1335), ('us', 1320), ('best', 1309), ('pretty', 1274), ('got', 1271), ('he', 1250), ('after', 1242), ('she', 1219), ('much', 1203), ('chicken', 1197), ('try', 1176), ('ordered', 1151), ('restaurant', 1149), ('am', 1148), ('menu', 1125), ('people', 1111), ('know', 1090), ('think', 1089), ('could', 1080), ('didnt', 1080), ('first', 1078), ('order', 1071), ('make', 1056), ('went', 1050), ('over', 1045), ('never', 1041), ('staff', 1029), ('friendly', 1027), ('bar', 1023), ('did', 1016), ('better', 1010), ('then', 1002), ('night', 993), ('way', 992), ('who', 987), ('going', 986), ('off', 982), ('how', 970), ('right', 945), ('few', 939), ('cheese', 922), ('came', 914), ('say', 908), ('two', 906), ('pizza', 900), ('made', 898), ('want', 896), ('delicious', 890), ('come', 881), ('salad', 869), ('any', 864), ('new', 848), ('now', 845), ('lunch', 840), ('still', 839), ('again', 833), ('sauce', 831), ('take', 815), ('fresh', 815), ('before', 796), ('see', 792), ('while', 788), ('sure', 784), ('since', 777), ('cant', 774), ('eat', 774), ('experience', 769), ('definitely', 765), ('find', 758), ('around', 756), ('her', 755), ('day', 755), ('something', 753), ('down', 751), ('wait', 746), ('happy', 745), ('most', 742), ('every', 734), ('many', 734), ('ever', 729), ('bit', 729), ('times', 726), ('amazing', 717), ('everything', 717), ('give', 707), ('though', 705), ('said', 702), ('table', 695), ('into', 693), ('next', 692), ('dinner', 688), ('area', 688), ('bad', 687), ('lot', 683), ('location', 681), ('thing', 676), ('being', 668), ('meal', 663), ('where', 662), ('both', 656), ('small', 651), ('last', 651), ('hour', 649), ('side', 635), ('phoenix', 629), ('prices', 624), ('another', 622), ('favorite', 622), ('youre', 615), ('wasnt', 603), ('big', 598), ('hot', 586), ('sandwich', 584), ('drink', 577), ('things', 574), ('home', 571), ('beer', 571), ('store', 569), ('his', 569), ('thats', 561), ('sweet', 560), ('tasty', 558), ('burger', 557), ('stars', 556), ('drinks', 556), ('minutes', 555), ('feel', 555), ('wine', 548), ('worth', 544), ('enough', 542), ('looking', 542), ('should', 542), ('took', 540), ('long', 538), ('friends', 534), ('fries', 531), ('work', 530), ('different', 529), ('bread', 528), ('awesome', 525), ('need', 525), ('atmosphere', 523), ('tried', 514), ('taste', 509), ('recommend', 509), ('room', 508), ('years', 504), ('huge', 504), ('old', 500), ('excellent', 498), ('price', 498), ('clean', 495), ('actually', 492), ('breakfast', 486), ('asked', 486), ('these', 485), ('selection', 482), ('those', 481), ('coffee', 477), ('places', 472), ('id', 470), ('found', 469), ('visit', 463), ('once', 463), ('meat', 4 ...

# %%
def generate_bbow_vector(words, sentence):
    sentence = pre_process(sentence)
    vector = np.zeros(10000)
    for word in filter(None, sentence.split(' ')):
        if(word in words):
            vector[words.index(word)] = 1
    return vector

def generate_freq_vector(words, sentence):
    sentence = pre_process(sentence)
    vector = np.zeros(10000)
    total_words_in_vocab = 0
    for word in filter(None, sentence.split(' ')):
        if(word in words):
            total_words_in_vocab += 1.
            vector[words.index(word)] += 1.
    for i in range(0, len(vector)):
        vector[i] = vector[i] / total_words_in_vocab
    return vector

# %%
#Yelp test
vocabulary = get_vocabulary(yelp_train)
vocab_words = [i[0] for i in vocabulary]
print(generate_bbow_vector(vocab_words, "willow and of the"))
print(generate_freq_vector(vocab_words, "willow asdlkfjalsdfk and and of the"))
# Out:
# [ 1.  1.  0. ...,  0.  0.  1.]
# [ 0.2  0.4  0.  ...,  0.   0.   0.2]

# %%
#IMDB test
vocabulary = get_vocabulary(imdb_train)
vocab_words = [i[0] for i in vocabulary]
print(generate_bbow_vector(vocab_words, "willow and of the"))
print(generate_freq_vector(vocab_words, "willow asdlkfjalsdfk and and of the"))
